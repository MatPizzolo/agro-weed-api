# %% [markdown]
# # Exploración del dataset DeepWeeds
#
# 8 especies de malezas + negativo. Explorar distribución de clases, tamaños de imagen y ejemplos por clase.

# %%
from weed_api.labels import LABELS, NUM_CLASSES

print(NUM_CLASSES, LABELS)
